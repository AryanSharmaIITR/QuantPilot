# %%
import pandas as pd

# %%
df1=pd.read_csv("../data/preprocessed/stock_data/cipla.csv")
df2=pd.read_csv("../data/preprocessed/market_data/crudeoilfutures.csv")

# %%
df1.tail()
# Out:
#            Date  day_return_scaled        RSI   Sortino      MACD  \
# 735  2026-03-25          17.747668  53.060888 -0.525406  1.000655
# 736  2026-03-27          12.882225  55.942987 -0.353780 -0.397876
# 737  2026-03-30          -5.685510  43.699438 -0.558707 -0.007870
# 738  2026-04-01         -47.091614  34.649466 -0.581060  3.600830
# 739  2026-04-02           2.016827  49.691832 -0.588650  2.469642
#
#      emaslope_15d         tr    atr_15d  bb_width_15d  zscore_15d   ret_15d  \
# 735      3.033311  30.379228  12.116754    -17.297123    1.751712 -1.683640
# 736      2.045967   4.865443  10.127354    -19.816103    1.274807  0.472942
# 737     -0.530746  18.567735  10.535804    -18.828166   -0.260070  0.538677
# 738     -5.640166  41.406104  12.235002     -9.793515   -2.545811 -4.852683
# 739      1.203410  49.108441  15.223127     -9.052474    0.570926 -0.745880
#
#      max_dd_15d     vol_15d  sharpe_ratio_15   var95_15  cvar95_15   beta_15  \
# ...

# %%
df2.tail()
# Out:
#            Date  day_return_scaled        RSI   Sortino      MACD  \
# 750  2026-03-27          67.838410  55.962135  0.098845 -4.458512
# 751  2026-03-30           2.729033  51.633951  0.141285 -3.198250
# 752  2026-03-31         -35.119468  47.845483  0.087559  0.844835
# 753  2026-04-01         -15.729438  44.930470 -0.057070  2.456084
# 754  2026-04-02         127.577871  55.614205  0.119239 -7.741453
#
#      emaslope_15d          tr    atr_15d  bb_width_15d  zscore_15d   ret_15d  \
# 750      7.889536   33.914069  68.516202    106.124499    1.260609 -0.546137
# 751     -1.235328   65.109377  60.694954     47.235117   -0.031540 -1.082800
# 752     -5.811975   37.848500  62.809052     54.543638   -0.751903  0.309344
# 753     -2.661724   19.390029  62.037363     84.186816   -0.350005 -4.796468
# 754     15.584405  143.307309  67.083096     38.023893    2.062399  0.777730
#
#      max_dd_15d     vol_15d  sharpe_ratio_15   var95_15  cvar95_15   beta_15  \
# ...

# %%
df1.isnull().sum()
# Out:
# Date                 0
# day_return_scaled    0
# RSI                  0
# Sortino              0
# MACD                 0
# emaslope_15d         0
# tr                   0
# atr_15d              0
# bb_width_15d         0
# zscore_15d           0
# ret_15d              0
# max_dd_15d           0
# vol_15d              0
# sharpe_ratio_15      0
# var95_15             0
# cvar95_15            0
# beta_15              0
# alpha_5d             0
# Target               1
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Date                 0
# day_return_scaled    0
# RSI                  0
# Sortino              0
# MACD                 0
# emaslope_15d         0
# tr                   0
# atr_15d              0
# bb_width_15d         0
# zscore_15d           0
# ret_15d              0
# max_dd_15d           0
# vol_15d              0
# sharpe_ratio_15      0
# var95_15             0
# cvar95_15            0
# beta_15              0
# alpha_5d             0
# dtype: int64

# %%
import numpy as np

# %%
mask = np.isinf(df1.select_dtypes(include=[np.number])).any(axis=1)
df1[mask]
# Out:
# Empty DataFrame
# Columns: [Date, day_return_scaled, RSI, Sortino, MACD, emaslope_15d, tr, atr_15d, bb_width_15d, zscore_15d, ret_15d, max_dd_15d, vol_15d, sharpe_ratio_15, var95_15, cvar95_15, beta_15, alpha_5d]
# Index: []

# %%
mask = np.isinf(df2.select_dtypes(include=[np.number])).any(axis=1)
df2[mask]
# Out:
# Empty DataFrame
# Columns: [Date, day_return_scaled, RSI, Sortino, MACD, emaslope_15d, tr, atr_15d, bb_width_15d, zscore_15d, ret_15d, max_dd_15d, vol_15d, sharpe_ratio_15, var95_15, cvar95_15, beta_15, alpha_5d]
# Index: []
